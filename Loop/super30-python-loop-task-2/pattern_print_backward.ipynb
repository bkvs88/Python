# %% [markdown]
# # Print the following pattern
# # *****
# # ****
# # ***
# # **
# # *

# %%
counter=range(5,0,-1) #looping through numbers from 5 to 1 using range function
for i in counter: # looping through each number in the range
    print("*"*i) # printing a line of asterisks with a length equal to the current number
# Out:
# *****
# ****
# ***
# **
# *
