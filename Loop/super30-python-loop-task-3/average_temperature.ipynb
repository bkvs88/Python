# %% [markdown]
# ### find the average temperature.

# %%
temperatures = [32, 35, 28, 40, 38, 31, 42] #list of temperature values
total_temp=0 #initializing a variable to store the total sum of temperature values
for index,number in enumerate(temperatures,start=1): # looping through each temperature value in the list using enumerate to get both index and value, starting the index from 1
    total_temp=total_temp+number # adding the current temperature value to the total
    total=index # storing the total number of temperature values
print(f"Average temperature is {total_temp/total}")
# Out:
# Average temperature is 35.142857142857146
