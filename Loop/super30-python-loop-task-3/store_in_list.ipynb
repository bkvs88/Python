# %% [markdown]
# ### Accept 10 numbers from the user and store them in a list using a loop.

# %%
number_list=[ ]
for i in range(1,11):
    input_number=int(input("Enter number to store"))
    print(f"User Entered {input_number}")
    number_list.append(input_number)
print(number_list)
# Out:
# User Entered 1
# User Entered 2
# User Entered 56
# User Entered 34
# User Entered 34
# User Entered 23
# User Entered 42
# User Entered 43
# User Entered 43
# User Entered 65
# [1, 2, 56, 34, 34, 23, 42, 43, 43, 65]
