# %%
correct_password="" #initialize the variable to an empty string
while correct_password != "Password": # keep asking for the password until the correct password is entered
    correct_password = input("Enter the correct password: ") # ask the user to enter the password
